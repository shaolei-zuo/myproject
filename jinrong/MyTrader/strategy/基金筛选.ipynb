# %%
#计算夏普比率、最大回撤、波动率

# %%
import sys
sys.path.append('../')
from jqdatasdk import *
auth('18608169587', 'JQszuo123')

# %%
import data.Stock as st
import pandas as pd
import  numpy as np
import strategy.base as strat
import matplotlib.pyplot as plt
import app.time_relevent as tr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-ea07d1760cfd> in <module>
#       4 import strategy.base as strat
#       5 import matplotlib.pyplot as plt
# ----> 6 import app.time_relevent as tr
#
# ModuleNotFoundError: No module named 'app'

# %%
import requests
import json
import re

code = "501019"  # 基金代码
url = "http://fundgz.1234567.com.cn/js/%s.js"%code
# 浏览器头
headers = {'content-type': 'application/json',
           'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:22.0) Gecko/20100101 Firefox/22.0'}

r = requests.get(url, headers=headers)
# 返回信息
content = r.text
# content = """jsonpgz({"fundcode":"501019","name":"国泰国证航天军工指数","jzrq":"2020-08-13","dwjz":"1.2327","gsz":"1.2690","gszzl":"2.95","gztime":"2020-08-14 15:00"});"""

# 正则表达式
pattern = r'^jsonpgz\((.*)\)'
# 查找结果
search = re.findall(pattern, content)
# 遍历结果
for i in search:
  data = json.loads(i)
  # print(data,type(data))
  print("基金: {},收益率: {}".format(data['name'],data['gsz']))
# Out:
# 基金: 国泰国证航天军工指数,收益率: 1.1310

# %%
oblist = []

jijin = st.jijin()
jijin.jijin_normalize_code(['206009.OF'])
# Out:
# ['206009.XSHE']

# %%
#get_all_securities(['mixture_fund'])

# %%
get_price('510300.XSHG',start_date='2021-01-01 00:00:00',end_date='2021-04-22 00:00:00')
# Out:
#              open  close   high    low        volume         money
# 2021-01-04  5.211  5.265  5.296  5.191  5.133950e+08  2.697193e+09
# 2021-01-05  5.252  5.362  5.374  5.236  6.310532e+08  3.349891e+09
# 2021-01-06  5.376  5.411  5.442  5.346  3.798950e+08  2.048972e+09
# 2021-01-07  5.418  5.526  5.527  5.412  4.768727e+08  2.604547e+09
# 2021-01-08  5.535  5.498  5.558  5.447  7.067737e+08  3.884323e+09
# 2021-01-11  5.499  5.436  5.547  5.406  6.443609e+08  3.536919e+09
# 2021-01-12  5.424  5.594  5.598  5.420  6.041526e+08  3.327362e+09
# 2021-01-13  5.610  5.572  5.641  5.537  5.597274e+08  3.129879e+09
# 2021-01-14  5.572  5.471  5.572  5.466  7.052369e+08  3.885748e+09
# 2021-01-15  5.471  5.454  5.503  5.389  7.184098e+08  3.916989e+09
# 2021-01-18  5.451  5.513  5.547  5.415  3.967686e+08  2.176481e+09
# 2021-01-19  5.518  5.438  5.530  5.416  4.170097e+08  2.282323e+09
# 2021-01-20  5.436  5.468  5.495  5.430  4.223858e+08  2.307752e+09
# ...

# %%
jijin.jijin_get_price('206009.OF',start_date='2021-01-01 00:00:00',end_date='2021-04-22 00:00:00')
# Out:
#             open  close  high  low  volume  money
# 2021-01-04   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-05   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-06   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-07   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-08   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-11   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-12   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-13   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-14   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-15   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-18   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-19   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-20   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-21   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-22   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-25   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-26   NaN    NaN   NaN  NaN     NaN    NaN
# 2021-01-27   NaN    NaN   NaN  NaN     NaN    NaN
# ...

# %%
get_security_info('206009.OF')
# Out:
# 206009.OF

# %%
get_security_info('510300.XSHG')
# Out:
# 510300.XSHG

# %%
df = get_price('510300.XSHG', start_date='2018-08-01 10:00:00', end_date='2018-08-01 10:05:00', frequency='1m')
